# %% [markdown]
# # Заголовок первого уровня
# ## Заголовок второго уровня
# ### Заголовок третьего уровня
# #### Заголовок четвертого уровня
# ##### Заголовок пятого уровня
# ###### Заголовок шестого уровня

# %% [markdown]
# > Блочная цитата

# %% [markdown]
#     a plain code block

# %% [markdown]
# **жирный** <br>
# *курсив*

# %% [markdown]
# `Monospaced text (e.g., code)`

# %% [markdown]
# ~~Вычеркнутый текст~~

# %% [markdown]
# Верхний индекс $s^2$
#
# $$E=mc^2$$

# %% [markdown]
# [Гиперссылка](https://rmarkdown.rstudio.com/)

# %% [markdown]
# ---

# %% [markdown]
# Нумерованный список:
# - Пункт 1
# - Пункт 2
#     - подпункт 1
#     - подпункт 2
#
# Упорядоченный список:
# <ol>
#   <li>Пункт 1</li>
#   <li>Пункт 2
#     <ol type="a">
#       <li>подпункт 1</li>
#       <li>подпункт 2</li>
#     </ol>
#   </li>
# </ol>

# %% [markdown]
# |Заголовок 1|Заголовок 2|
# |-----------|-----------|
# |Ячейка 1   |Ячейка 2   |
# |Ячейка 3   |Ячейка 4   |
